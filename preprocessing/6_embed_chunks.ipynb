# %%
import pandas as pd 
from dotenv import load_dotenv
import json
from openai import OpenAI
import os 
import numpy as np
import base64
import time 

MIN_COUNT = 25
STRIDE = 20
LENGTH = 40

MODEL = "text-embedding-3-small"
EMBED_DIM = 512
PRECISION = np.float16
PRECISION_STR = 'f16'

IN_FILE = f'data/combined_chunks_top{MIN_COUNT}_len{LENGTH}_stride{STRIDE}.jsonl'
OUT_FILE = f'D:/embed_top{MIN_COUNT}_len{LENGTH}_stride{STRIDE}_dim{EMBED_DIM}_type{PRECISION_STR}.jsonl'

total_tokens = 0

# Calc total chunks
# with open(IN_FILE, 'r') as file:
#     for total_chunks, line in enumerate(file):
#         pass
# print(total_chunks)
total_chunks = 17582505

COST_PER_TOKEN = .01 / 1000000

CHUNKS_PER_BATCH = 1000

# %%
def embed_chunk(df, i, client, window):
    window = df.iloc[i : i + window]
    chunk_ids = window['chunk_id'].values.tolist()
    article_ids = window['article_id'].values.tolist()

    try:
        result = client.embeddings.create(
            input=window['chunk'].values.tolist(),
            model=MODEL,
            dimensions=EMBED_DIM
        )
    except Exception as e:
        print(e)
        return [
            {'chunk_id': x, 'embedding': None} 
            for x in chunk_ids
        ]

    global total_tokens
    total_tokens += result.usage.total_tokens

    return [
        {
            'chunk_id': chunk_ids[i], 
            'article_id': article_ids[i],
            'embedding': base64.b64encode(np.array(x.embedding, dtype=PRECISION)).decode('utf-8'),
            'model': MODEL
        } 
        for i, x in enumerate(result.data)
    ]

def append_to_disk(embeddings):
    with open(OUT_FILE, 'a', encoding='utf-8') as file:
        for row in embeddings:
            file.write(json.dumps(row) + '\n')

def embed_df(df, client, last_idx, start):
    global total_tokens
    i = 0
    while i + CHUNKS_PER_BATCH < len(df):
        append_to_disk(embed_chunk(df, i, client, CHUNKS_PER_BATCH))
        i += CHUNKS_PER_BATCH
        print(f"\nChunks embedded: {last_idx} ({round(last_idx / total_chunks, 5)}%). Total tokens spent: {total_tokens}. (${round(total_tokens * COST_PER_TOKEN, 3)}). Total time: {round((time.time() - start) / 60, 2)} minutes. Chunks per second: {round(last_idx / (time.time() - start), 1)}. Projected total hours: {round((((time.time() - start) / last_idx) * total_chunks) / 3600, 2)}")
    
    if i < len(df):
        append_to_disk(embed_chunk(df, i, client, CHUNKS_PER_BATCH))

# %%
load_dotenv()

client = OpenAI(api_key=os.environ.get("API_KEY"))

df = []
start = time.time()
with open(IN_FILE, 'r') as file:
    for idx, line in enumerate(file):
        df.append(json.loads(line.strip()))
        if idx != 0 and idx % 10000 == 0:
            embed_df(pd.DataFrame(df), client, idx, start)
            df = []
# Out:
# Chunks embedded: 1000 (0.00057%). Total tokens spent: 53303. ($0.001). Total time: 0.04 minutes. Chunks per second: 4102.4. Projected total hours: 1.19
#
# Chunks embedded: 2000 (0.00057%). Total tokens spent: 107940. ($0.001). Total time: 0.08 minutes. Chunks per second: 2192.8. Projected total hours: 2.23
#
# Chunks embedded: 3000 (0.00057%). Total tokens spent: 160257. ($0.002). Total time: 0.12 minutes. Chunks per second: 1415.1. Projected total hours: 3.45
#
# Chunks embedded: 4000 (0.00057%). Total tokens spent: 212050. ($0.002). Total time: 0.16 minutes. Chunks per second: 1048.3. Projected total hours: 4.66
#
# Chunks embedded: 5000 (0.00057%). Total tokens spent: 267630. ($0.003). Total time: 0.2 minutes. Chunks per second: 821.1. Projected total hours: 5.95
#
# Chunks embedded: 6000 (0.00057%). Total tokens spent: 323728. ($0.003). Total time: 0.24 minutes. Chunks per second: 688.9. Projected total hours: 7.09
#
# Chunks embedded: 7000 (0.00057%). Total tokens spent: 379509. ($0.004). Total time: 0.28 minutes. Chunks per second: 598.6. Projected total hours: 8.16
#
# Chunks embedded: 8000 (0.00057%). Total tokens spent: 437946. ($0.004). Total time: 0.32 minutes. Chunks per second: 520.0. Projected total hours: 9.39
#
# Chunks embedded: 9000 (0.00057%). Total tokens spent: 491769. ($0.005). Total time: 0.37 minutes. Chunks per second: 456.6. Projected total hours: 10.7
#
# Chunks embedded: 10000 (0.00057%). Total tokens spent: 546244. ($0.005). Total time: 0.42 minutes. Chunks per second: 397.7. Projected total hours: 12.28
#
# Chunks embedded: 1000 (0.00114%). Total tokens spent: 601228. ($0.006). Total time: 0.47 minutes. Chunks per second: 708.9. Projected total hours: 6.89
#
# Chunks embedded: 2000 (0.00114%). Total tokens spent: 656882. ($0.007). Total time: 0.51 minutes. Chunks per second: 648.1. Projected total hours: 7.54
#
# Chunks embedded: 3000 (0.00114%). Total tokens spent: 710307. ($0.007). Total time: 0.56 minutes. Chunks per second: 592.4. Projected total hours: 8.24
#
# Chunks embedded: 4000 (0.00114%). Total tokens spent: 762711. ($0.008). Total time: 0.6 minutes. Chunks per second: 553.7. Projected total hours: 8.82
#
# Chunks embedded: 5000 (0.00114%). Total tokens spent: 817897. ($0.008). Total time: 0.68 minutes. Chunks per second: 493.5. Projected total hours: 9.9
#
# Chunks embedded: 6000 (0.00114%). Total tokens spent: 872516. ($0.009). Total time: 0.73 minutes. Chunks per second: 456.8. Projected total hours: 10.69
#
# Chunks embedded: 7000 (0.00114%). Total tokens spent: 926234. ($0.009). Total time: 0.77 minutes. Chunks per second: 430.2. Projected total hours: 11.35
#
# Chunks embedded: 8000 (0.00114%). Total tokens spent: 978737. ($0.01). Total time: 0.84 minutes. Chunks per second: 398.2. Projected total hours: 12.26
#
# Chunks embedded: 9000 (0.00114%). Total tokens spent: 1034001. ($0.01). Total time: 0.9 minutes. Chunks per second: 371.7. Projected total hours: 13.14
#
# Chunks embedded: 1000 (0.00171%). Total tokens spent: 1144687. ($0.011). Total time: 0.99 minutes. Chunks per second: 504.9. Projected total hours: 9.67
#
# Chunks embedded: 2000 (0.00171%). Total tokens spent: 1199576. ($0.012). Total time: 1.04 minutes. Chunks per second: 481.0. Projected total hours: 10.15
#
# Chunks embedded: 3000 (0.00171%). Total tokens spent: 1254501. ($0.013). Total time: 1.09 minutes. Chunks per second: 458.4. Projected total hours: 10.66
#
# Chunks embedded: 4000 (0.00171%). Total tokens spent: 1305462. ($0.013). Total time: 1.13 minutes. Chunks per second: 443.5. Projected total hours: 11.01
#
# Chunks embedded: 5000 (0.00171%). Total tokens spent: 1357136. ($0.014). Total time: 1.17 minutes. Chunks per second: 428.6. Projected total hours: 11.4
#
# Chunks embedded: 6000 (0.00171%). Total tokens spent: 1411502. ($0.014). Total time: 1.21 minutes. Chunks per second: 413.3. Projected total hours: 11.82
#
# Chunks embedded: 7000 (0.00171%). Total tokens spent: 1467431. ($0.015). Total time: 1.25 minutes. Chunks per second: 400.8. Projected total hours: 12.19
#
# Chunks embedded: 8000 (0.00171%). Total tokens spent: 1523150. ($0.015). Total time: 1.29 minutes. Chunks per second: 387.9. Projected total hours: 12.59
#
# Chunks embedded: 9000 (0.00171%). Total tokens spent: 1579516. ($0.016). Total time: 1.33 minutes. Chunks per second: 374.8. Projected total hours: 13.03
#
# Chunks embedded: 1000 (0.00227%). Total tokens spent: 1691980. ($0.017). Total time: 1.42 minutes. Chunks per second: 468.0. Projected total hours: 10.44
#
# Chunks embedded: 2000 (0.00227%). Total tokens spent: 1747041. ($0.017). Total time: 1.47 minutes. Chunks per second: 454.9. Projected total hours: 10.74
#
# Chunks embedded: 3000 (0.00227%). Total tokens spent: 1800466. ($0.018). Total time: 1.5 minutes. Chunks per second: 443.4. Projected total hours: 11.01
#
# Chunks embedded: 4000 (0.00227%). Total tokens spent: 1854099. ($0.019). Total time: 1.55 minutes. Chunks per second: 429.2. Projected total hours: 11.38
#
# Chunks embedded: 5000 (0.00227%). Total tokens spent: 1907603. ($0.019). Total time: 1.6 minutes. Chunks per second: 416.5. Projected total hours: 11.73
#
# Chunks embedded: 6000 (0.00227%). Total tokens spent: 1962911. ($0.02). Total time: 1.64 minutes. Chunks per second: 407.2. Projected total hours: 12.0
#
# Chunks embedded: 7000 (0.00227%). Total tokens spent: 2017682. ($0.02). Total time: 1.68 minutes. Chunks per second: 397.2. Projected total hours: 12.3
#
# Chunks embedded: 8000 (0.00227%). Total tokens spent: 2073337. ($0.021). Total time: 1.72 minutes. Chunks per second: 388.6. Projected total hours: 12.57
#
# Chunks embedded: 9000 (0.00227%). Total tokens spent: 2130637. ($0.021). Total time: 1.76 minutes. Chunks per second: 378.4. Projected total hours: 12.91
#
# Chunks embedded: 1000 (0.00284%). Total tokens spent: 2239776. ($0.022). Total time: 1.86 minutes. Chunks per second: 448.7. Projected total hours: 10.88
#
# Chunks embedded: 2000 (0.00284%). Total tokens spent: 2297757. ($0.023). Total time: 1.9 minutes. Chunks per second: 439.7. Projected total hours: 11.11
#
# Chunks embedded: 3000 (0.00284%). Total tokens spent: 2353049. ($0.024). Total time: 1.93 minutes. Chunks per second: 430.9. Projected total hours: 11.34
#
# Chunks embedded: 4000 (0.00284%). Total tokens spent: 2408549. ($0.024). Total time: 1.98 minutes. Chunks per second: 421.6. Projected total hours: 11.59
#
# Chunks embedded: 5000 (0.00284%). Total tokens spent: 2463875. ($0.025). Total time: 2.01 minutes. Chunks per second: 414.3. Projected total hours: 11.79
#
# Chunks embedded: 6000 (0.00284%). Total tokens spent: 2520222. ($0.025). Total time: 2.05 minutes. Chunks per second: 406.6. Projected total hours: 12.01
#
# Chunks embedded: 7000 (0.00284%). Total tokens spent: 2591185. ($0.026). Total time: 2.09 minutes. Chunks per second: 398.1. Projected total hours: 12.27
#
# Chunks embedded: 8000 (0.00284%). Total tokens spent: 2655416. ($0.027). Total time: 2.15 minutes. Chunks per second: 388.1. Projected total hours: 12.58
#
# Chunks embedded: 9000 (0.00284%). Total tokens spent: 2713620. ($0.027). Total time: 2.19 minutes. Chunks per second: 380.6. Projected total hours: 12.83
#
# Chunks embedded: 1000 (0.00341%). Total tokens spent: 2827985. ($0.028). Total time: 2.28 minutes. Chunks per second: 437.9. Projected total hours: 11.15
#
# Chunks embedded: 2000 (0.00341%). Total tokens spent: 2884129. ($0.029). Total time: 2.34 minutes. Chunks per second: 427.2. Projected total hours: 11.43
#
# Chunks embedded: 3000 (0.00341%). Total tokens spent: 2944196. ($0.029). Total time: 2.4 minutes. Chunks per second: 417.4. Projected total hours: 11.7
#
# Chunks embedded: 4000 (0.00341%). Total tokens spent: 2996357. ($0.03). Total time: 2.5 minutes. Chunks per second: 400.2. Projected total hours: 12.2
#
# Chunks embedded: 5000 (0.00341%). Total tokens spent: 3052128. ($0.031). Total time: 2.54 minutes. Chunks per second: 393.0. Projected total hours: 12.43
#
# Chunks embedded: 6000 (0.00341%). Total tokens spent: 3109584. ($0.031). Total time: 2.58 minutes. Chunks per second: 387.2. Projected total hours: 12.61
#
# Chunks embedded: 7000 (0.00341%). Total tokens spent: 3164228. ($0.032). Total time: 2.65 minutes. Chunks per second: 377.0. Projected total hours: 12.96
#
# Chunks embedded: 8000 (0.00341%). Total tokens spent: 3223711. ($0.032). Total time: 2.72 minutes. Chunks per second: 368.2. Projected total hours: 13.27
#
# Chunks embedded: 9000 (0.00341%). Total tokens spent: 3277681. ($0.033). Total time: 2.78 minutes. Chunks per second: 359.4. Projected total hours: 13.59
#
# Chunks embedded: 1000 (0.00398%). Total tokens spent: 3384026. ($0.034). Total time: 2.93 minutes. Chunks per second: 398.0. Projected total hours: 12.27
#
# Chunks embedded: 2000 (0.00398%). Total tokens spent: 3436685. ($0.034). Total time: 2.98 minutes. Chunks per second: 392.0. Projected total hours: 12.46
#
# Chunks embedded: 3000 (0.00398%). Total tokens spent: 3488915. ($0.035). Total time: 3.03 minutes. Chunks per second: 385.4. Projected total hours: 12.67
#
# Chunks embedded: 4000 (0.00398%). Total tokens spent: 3543714. ($0.035). Total time: 3.09 minutes. Chunks per second: 377.6. Projected total hours: 12.93
#
# Chunks embedded: 5000 (0.00398%). Total tokens spent: 3599976. ($0.036). Total time: 3.16 minutes. Chunks per second: 369.6. Projected total hours: 13.22
#
# Chunks embedded: 6000 (0.00398%). Total tokens spent: 3660407. ($0.037). Total time: 3.22 minutes. Chunks per second: 362.7. Projected total hours: 13.46
#
# Chunks embedded: 7000 (0.00398%). Total tokens spent: 3720660. ($0.037). Total time: 3.3 minutes. Chunks per second: 354.0. Projected total hours: 13.8
#
# Chunks embedded: 8000 (0.00398%). Total tokens spent: 3774048. ($0.038). Total time: 3.35 minutes. Chunks per second: 348.5. Projected total hours: 14.01
#
# Chunks embedded: 9000 (0.00398%). Total tokens spent: 3828591. ($0.038). Total time: 3.41 minutes. Chunks per second: 342.3. Projected total hours: 14.27
#
# Chunks embedded: 1000 (0.00455%). Total tokens spent: 3949603. ($0.039). Total time: 3.53 minutes. Chunks per second: 377.9. Projected total hours: 12.93
#
# Chunks embedded: 2000 (0.00455%). Total tokens spent: 4005913. ($0.04). Total time: 3.6 minutes. Chunks per second: 370.1. Projected total hours: 13.2
#
# Chunks embedded: 3000 (0.00455%). Total tokens spent: 4060282. ($0.041). Total time: 3.67 minutes. Chunks per second: 363.6. Projected total hours: 13.43
#
# Chunks embedded: 4000 (0.00455%). Total tokens spent: 4114530. ($0.041). Total time: 3.72 minutes. Chunks per second: 358.0. Projected total hours: 13.64
#
# Chunks embedded: 5000 (0.00455%). Total tokens spent: 4169579. ($0.042). Total time: 3.78 minutes. Chunks per second: 352.7. Projected total hours: 13.85
#
# Chunks embedded: 6000 (0.00455%). Total tokens spent: 4227549. ($0.042). Total time: 3.86 minutes. Chunks per second: 345.6. Projected total hours: 14.13
#
# Chunks embedded: 7000 (0.00455%). Total tokens spent: 4286525. ($0.043). Total time: 3.91 minutes. Chunks per second: 340.9. Projected total hours: 14.33
#
# Chunks embedded: 8000 (0.00455%). Total tokens spent: 4342911. ($0.043). Total time: 3.97 minutes. Chunks per second: 335.5. Projected total hours: 14.56
#
# Chunks embedded: 9000 (0.00455%). Total tokens spent: 4405655. ($0.044). Total time: 4.03 minutes. Chunks per second: 330.7. Projected total hours: 14.77
#
# Chunks embedded: 1000 (0.00512%). Total tokens spent: 4520462. ($0.045). Total time: 4.17 minutes. Chunks per second: 360.1. Projected total hours: 13.56
#
# Chunks embedded: 2000 (0.00512%). Total tokens spent: 4578910. ($0.046). Total time: 4.23 minutes. Chunks per second: 355.0. Projected total hours: 13.76
#
# Chunks embedded: 3000 (0.00512%). Total tokens spent: 4644229. ($0.046). Total time: 4.29 minutes. Chunks per second: 350.0. Projected total hours: 13.95
#
# Chunks embedded: 4000 (0.00512%). Total tokens spent: 4703093. ($0.047). Total time: 4.35 minutes. Chunks per second: 345.0. Projected total hours: 14.16
#
# Chunks embedded: 5000 (0.00512%). Total tokens spent: 4756476. ($0.048). Total time: 4.41 minutes. Chunks per second: 339.8. Projected total hours: 14.37
#
# Chunks embedded: 6000 (0.00512%). Total tokens spent: 4819479. ($0.048). Total time: 4.48 minutes. Chunks per second: 335.0. Projected total hours: 14.58
#
# Chunks embedded: 7000 (0.00512%). Total tokens spent: 4875649. ($0.049). Total time: 4.54 minutes. Chunks per second: 330.3. Projected total hours: 14.79
#
# Chunks embedded: 8000 (0.00512%). Total tokens spent: 4931839. ($0.049). Total time: 4.59 minutes. Chunks per second: 326.6. Projected total hours: 14.96
#
# Chunks embedded: 9000 (0.00512%). Total tokens spent: 4988758. ($0.05). Total time: 4.66 minutes. Chunks per second: 322.1. Projected total hours: 15.16
#
# Chunks embedded: 1000 (0.00569%). Total tokens spent: 5098864. ($0.051). Total time: 4.79 minutes. Chunks per second: 347.6. Projected total hours: 14.05
#
# Chunks embedded: 2000 (0.00569%). Total tokens spent: 5152891. ($0.052). Total time: 4.86 minutes. Chunks per second: 343.0. Projected total hours: 14.24
#
# Chunks embedded: 3000 (0.00569%). Total tokens spent: 5215119. ($0.052). Total time: 4.91 minutes. Chunks per second: 339.3. Projected total hours: 14.39
#
# Chunks embedded: 4000 (0.00569%). Total tokens spent: 5272389. ($0.053). Total time: 4.97 minutes. Chunks per second: 335.1. Projected total hours: 14.57
#
# Chunks embedded: 5000 (0.00569%). Total tokens spent: 5330193. ($0.053). Total time: 5.04 minutes. Chunks per second: 330.5. Projected total hours: 14.78
#
# Chunks embedded: 6000 (0.00569%). Total tokens spent: 5385210. ($0.054). Total time: 5.1 minutes. Chunks per second: 326.7. Projected total hours: 14.95
#
# Chunks embedded: 7000 (0.00569%). Total tokens spent: 5443064. ($0.054). Total time: 5.16 minutes. Chunks per second: 322.9. Projected total hours: 15.12
#
# Chunks embedded: 8000 (0.00569%). Total tokens spent: 5505190. ($0.055). Total time: 5.23 minutes. Chunks per second: 318.9. Projected total hours: 15.31
#
# Chunks embedded: 9000 (0.00569%). Total tokens spent: 5561801. ($0.056). Total time: 5.28 minutes. Chunks per second: 315.6. Projected total hours: 15.47
#
# Chunks embedded: 1000 (0.00626%). Total tokens spent: 5676241. ($0.057). Total time: 5.42 minutes. Chunks per second: 338.2. Projected total hours: 14.44
#
# Chunks embedded: 2000 (0.00626%). Total tokens spent: 5740025. ($0.057). Total time: 5.48 minutes. Chunks per second: 334.5. Projected total hours: 14.6
#
# Chunks embedded: 3000 (0.00626%). Total tokens spent: 5801977. ($0.058). Total time: 5.54 minutes. Chunks per second: 331.1. Projected total hours: 14.75
#
# Chunks embedded: 4000 (0.00626%). Total tokens spent: 5856272. ($0.059). Total time: 5.6 minutes. Chunks per second: 327.2. Projected total hours: 14.93
#
# Chunks embedded: 5000 (0.00626%). Total tokens spent: 5915291. ($0.059). Total time: 5.67 minutes. Chunks per second: 323.4. Projected total hours: 15.1
#
# Chunks embedded: 6000 (0.00626%). Total tokens spent: 5973304. ($0.06). Total time: 5.73 minutes. Chunks per second: 319.7. Projected total hours: 15.28
#
# Chunks embedded: 7000 (0.00626%). Total tokens spent: 6026069. ($0.06). Total time: 5.79 minutes. Chunks per second: 316.5. Projected total hours: 15.43
#
# Chunks embedded: 8000 (0.00626%). Total tokens spent: 6085323. ($0.061). Total time: 5.85 minutes. Chunks per second: 313.1. Projected total hours: 15.6
#
# Chunks embedded: 9000 (0.00626%). Total tokens spent: 6140391. ($0.061). Total time: 5.92 minutes. Chunks per second: 309.8. Projected total hours: 15.76
#
# Chunks embedded: 1000 (0.00682%). Total tokens spent: 6249790. ($0.062). Total time: 6.05 minutes. Chunks per second: 330.5. Projected total hours: 14.78
#
# Chunks embedded: 2000 (0.00682%). Total tokens spent: 6304493. ($0.063). Total time: 6.12 minutes. Chunks per second: 326.6. Projected total hours: 14.96
#
# Chunks embedded: 3000 (0.00682%). Total tokens spent: 6358619. ($0.064). Total time: 6.19 minutes. Chunks per second: 323.2. Projected total hours: 15.11
#
# Chunks embedded: 4000 (0.00682%). Total tokens spent: 6412207. ($0.064). Total time: 6.24 minutes. Chunks per second: 320.6. Projected total hours: 15.24
#
# Chunks embedded: 5000 (0.00682%). Total tokens spent: 6464494. ($0.065). Total time: 6.31 minutes. Chunks per second: 317.2. Projected total hours: 15.4
#
# Chunks embedded: 6000 (0.00682%). Total tokens spent: 6516286. ($0.065). Total time: 6.37 minutes. Chunks per second: 314.1. Projected total hours: 15.55
#
# Chunks embedded: 7000 (0.00682%). Total tokens spent: 6568234. ($0.066). Total time: 6.44 minutes. Chunks per second: 310.8. Projected total hours: 15.71
#
# Chunks embedded: 8000 (0.00682%). Total tokens spent: 6619250. ($0.066). Total time: 6.5 minutes. Chunks per second: 307.9. Projected total hours: 15.86
#
# Chunks embedded: 9000 (0.00682%). Total tokens spent: 6670176. ($0.067). Total time: 6.55 minutes. Chunks per second: 305.1. Projected total hours: 16.01
#
# Chunks embedded: 1000 (0.00739%). Total tokens spent: 6786416. ($0.068). Total time: 6.68 minutes. Chunks per second: 324.3. Projected total hours: 15.06
#
# Chunks embedded: 2000 (0.00739%). Total tokens spent: 6840707. ($0.068). Total time: 6.75 minutes. Chunks per second: 321.0. Projected total hours: 15.21
#
# Chunks embedded: 3000 (0.00739%). Total tokens spent: 6896246. ($0.069). Total time: 6.8 minutes. Chunks per second: 318.5. Projected total hours: 15.34
#
# Chunks embedded: 4000 (0.00739%). Total tokens spent: 6953405. ($0.07). Total time: 6.87 minutes. Chunks per second: 315.5. Projected total hours: 15.48
#
# Chunks embedded: 5000 (0.00739%). Total tokens spent: 7006475. ($0.07). Total time: 6.93 minutes. Chunks per second: 312.6. Projected total hours: 15.62
#
# Chunks embedded: 6000 (0.00739%). Total tokens spent: 7062520. ($0.071). Total time: 7.0 minutes. Chunks per second: 309.6. Projected total hours: 15.78
#
# Chunks embedded: 7000 (0.00739%). Total tokens spent: 7117071. ($0.071). Total time: 7.05 minutes. Chunks per second: 307.3. Projected total hours: 15.89
#
# Chunks embedded: 8000 (0.00739%). Total tokens spent: 7170026. ($0.072). Total time: 7.12 minutes. Chunks per second: 304.2. Projected total hours: 16.06
#
# Chunks embedded: 9000 (0.00739%). Total tokens spent: 7223083. ($0.072). Total time: 7.19 minutes. Chunks per second: 301.5. Projected total hours: 16.2
#
# Chunks embedded: 1000 (0.00796%). Total tokens spent: 7332052. ($0.073). Total time: 7.31 minutes. Chunks per second: 319.2. Projected total hours: 15.3
#
# Chunks embedded: 2000 (0.00796%). Total tokens spent: 7385820. ($0.074). Total time: 7.37 minutes. Chunks per second: 316.7. Projected total hours: 15.42
#
# Chunks embedded: 3000 (0.00796%). Total tokens spent: 7440980. ($0.074). Total time: 7.44 minutes. Chunks per second: 313.7. Projected total hours: 15.57
#
# Chunks embedded: 4000 (0.00796%). Total tokens spent: 7495302. ($0.075). Total time: 7.49 minutes. Chunks per second: 311.7. Projected total hours: 15.67
#
# Chunks embedded: 5000 (0.00796%). Total tokens spent: 7548362. ($0.075). Total time: 7.56 minutes. Chunks per second: 308.6. Projected total hours: 15.83
#
# Chunks embedded: 6000 (0.00796%). Total tokens spent: 7600341. ($0.076). Total time: 7.63 minutes. Chunks per second: 305.9. Projected total hours: 15.96
#
# Chunks embedded: 7000 (0.00796%). Total tokens spent: 7654809. ($0.077). Total time: 7.7 minutes. Chunks per second: 302.8. Projected total hours: 16.13
#
# Chunks embedded: 8000 (0.00796%). Total tokens spent: 7707825. ($0.077). Total time: 7.75 minutes. Chunks per second: 301.2. Projected total hours: 16.22
#
# Chunks embedded: 9000 (0.00796%). Total tokens spent: 7763339. ($0.078). Total time: 7.8 minutes. Chunks per second: 299.0. Projected total hours: 16.33
#
# Chunks embedded: 1000 (0.00853%). Total tokens spent: 7892939. ($0.079). Total time: 7.94 minutes. Chunks per second: 315.0. Projected total hours: 15.5
#
# Chunks embedded: 2000 (0.00853%). Total tokens spent: 7948037. ($0.079). Total time: 8.0 minutes. Chunks per second: 312.4. Projected total hours: 15.63
#
# Chunks embedded: 3000 (0.00853%). Total tokens spent: 8005123. ($0.08). Total time: 8.05 minutes. Chunks per second: 310.4. Projected total hours: 15.73
#
# Chunks embedded: 4000 (0.00853%). Total tokens spent: 8061100. ($0.081). Total time: 8.13 minutes. Chunks per second: 307.6. Projected total hours: 15.88
#
# Chunks embedded: 5000 (0.00853%). Total tokens spent: 8116295. ($0.081). Total time: 8.19 minutes. Chunks per second: 305.3. Projected total hours: 16.0
#
# Chunks embedded: 6000 (0.00853%). Total tokens spent: 8174793. ($0.082). Total time: 8.24 minutes. Chunks per second: 303.3. Projected total hours: 16.1
#
# Chunks embedded: 7000 (0.00853%). Total tokens spent: 8234517. ($0.082). Total time: 8.31 minutes. Chunks per second: 300.9. Projected total hours: 16.23
#
# Chunks embedded: 8000 (0.00853%). Total tokens spent: 8295599. ($0.083). Total time: 8.38 minutes. Chunks per second: 298.5. Projected total hours: 16.36
#
# Chunks embedded: 9000 (0.00853%). Total tokens spent: 8355170. ($0.084). Total time: 8.43 minutes. Chunks per second: 296.5. Projected total hours: 16.47
#
# Chunks embedded: 1000 (0.0091%). Total tokens spent: 8464582. ($0.085). Total time: 8.56 minutes. Chunks per second: 311.5. Projected total hours: 15.68
#
# Chunks embedded: 2000 (0.0091%). Total tokens spent: 8522821. ($0.085). Total time: 8.62 minutes. Chunks per second: 309.2. Projected total hours: 15.8
#
# Chunks embedded: 3000 (0.0091%). Total tokens spent: 8576317. ($0.086). Total time: 8.69 minutes. Chunks per second: 306.9. Projected total hours: 15.92
#
# Chunks embedded: 4000 (0.0091%). Total tokens spent: 8633302. ($0.086). Total time: 8.75 minutes. Chunks per second: 304.8. Projected total hours: 16.03
#
# Chunks embedded: 5000 (0.0091%). Total tokens spent: 8688062. ($0.087). Total time: 8.82 minutes. Chunks per second: 302.3. Projected total hours: 16.16
#
# Chunks embedded: 6000 (0.0091%). Total tokens spent: 8744080. ($0.087). Total time: 8.88 minutes. Chunks per second: 300.2. Projected total hours: 16.27
#
# Chunks embedded: 7000 (0.0091%). Total tokens spent: 8802822. ($0.088). Total time: 8.94 minutes. Chunks per second: 298.2. Projected total hours: 16.38
#
# Chunks embedded: 8000 (0.0091%). Total tokens spent: 8859253. ($0.089). Total time: 9.02 minutes. Chunks per second: 295.7. Projected total hours: 16.52
#
# Chunks embedded: 9000 (0.0091%). Total tokens spent: 8916344. ($0.089). Total time: 9.11 minutes. Chunks per second: 292.7. Projected total hours: 16.69
#
# Chunks embedded: 1000 (0.00967%). Total tokens spent: 9027920. ($0.09). Total time: 9.21 minutes. Chunks per second: 307.6. Projected total hours: 15.88
#
# Chunks embedded: 2000 (0.00967%). Total tokens spent: 9081080. ($0.091). Total time: 9.27 minutes. Chunks per second: 305.7. Projected total hours: 15.98
#
# Chunks embedded: 3000 (0.00967%). Total tokens spent: 9136182. ($0.091). Total time: 9.33 minutes. Chunks per second: 303.7. Projected total hours: 16.08
#
# Chunks embedded: 4000 (0.00967%). Total tokens spent: 9194854. ($0.092). Total time: 9.39 minutes. Chunks per second: 301.7. Projected total hours: 16.19
#
# Chunks embedded: 5000 (0.00967%). Total tokens spent: 9248224. ($0.092). Total time: 9.46 minutes. Chunks per second: 299.6. Projected total hours: 16.3
#
# Chunks embedded: 6000 (0.00967%). Total tokens spent: 9307645. ($0.093). Total time: 9.51 minutes. Chunks per second: 298.0. Projected total hours: 16.39
#
# Chunks embedded: 7000 (0.00967%). Total tokens spent: 9364016. ($0.094). Total time: 9.57 minutes. Chunks per second: 296.0. Projected total hours: 16.5
#
# Chunks embedded: 8000 (0.00967%). Total tokens spent: 9422893. ($0.094). Total time: 9.64 minutes. Chunks per second: 294.1. Projected total hours: 16.61
#
# Chunks embedded: 9000 (0.00967%). Total tokens spent: 9477783. ($0.095). Total time: 9.71 minutes. Chunks per second: 291.9. Projected total hours: 16.73
#
# Chunks embedded: 1000 (0.01024%). Total tokens spent: 9602941. ($0.096). Total time: 9.84 minutes. Chunks per second: 304.8. Projected total hours: 16.02
#
# Chunks embedded: 2000 (0.01024%). Total tokens spent: 9659880. ($0.097). Total time: 9.91 minutes. Chunks per second: 302.8. Projected total hours: 16.13
#
# Chunks embedded: 3000 (0.01024%). Total tokens spent: 9713542. ($0.097). Total time: 9.96 minutes. Chunks per second: 301.3. Projected total hours: 16.21
#
# Chunks embedded: 4000 (0.01024%). Total tokens spent: 9766407. ($0.098). Total time: 10.02 minutes. Chunks per second: 299.4. Projected total hours: 16.31
#
# Chunks embedded: 5000 (0.01024%). Total tokens spent: 9820528. ($0.098). Total time: 10.08 minutes. Chunks per second: 297.8. Projected total hours: 16.4
#
# Chunks embedded: 6000 (0.01024%). Total tokens spent: 9872671. ($0.099). Total time: 10.15 minutes. Chunks per second: 295.7. Projected total hours: 16.52
#
# Chunks embedded: 7000 (0.01024%). Total tokens spent: 9925637. ($0.099). Total time: 10.22 minutes. Chunks per second: 293.4. Projected total hours: 16.64
#
# Chunks embedded: 8000 (0.01024%). Total tokens spent: 9983174. ($0.1). Total time: 10.28 minutes. Chunks per second: 291.8. Projected total hours: 16.74
#
# Chunks embedded: 9000 (0.01024%). Total tokens spent: 10039488. ($0.1). Total time: 10.36 minutes. Chunks per second: 289.7. Projected total hours: 16.86
#
# Chunks embedded: 1000 (0.01081%). Total tokens spent: 10152220. ($0.102). Total time: 10.47 minutes. Chunks per second: 302.4. Projected total hours: 16.15
#
# Chunks embedded: 2000 (0.01081%). Total tokens spent: 10207497. ($0.102). Total time: 10.53 minutes. Chunks per second: 300.8. Projected total hours: 16.24
#
# Chunks embedded: 3000 (0.01081%). Total tokens spent: 10259817. ($0.103). Total time: 10.6 minutes. Chunks per second: 298.9. Projected total hours: 16.34
#
# Chunks embedded: 4000 (0.01081%). Total tokens spent: 10315500. ($0.103). Total time: 10.66 minutes. Chunks per second: 297.1. Projected total hours: 16.44
#
# Chunks embedded: 5000 (0.01081%). Total tokens spent: 10370453. ($0.104). Total time: 10.72 minutes. Chunks per second: 295.3. Projected total hours: 16.54
#
# Chunks embedded: 6000 (0.01081%). Total tokens spent: 10430359. ($0.104). Total time: 10.78 minutes. Chunks per second: 293.8. Projected total hours: 16.62
#
# Chunks embedded: 7000 (0.01081%). Total tokens spent: 10485444. ($0.105). Total time: 10.85 minutes. Chunks per second: 291.8. Projected total hours: 16.74
#
# Chunks embedded: 8000 (0.01081%). Total tokens spent: 10542349. ($0.105). Total time: 10.89 minutes. Chunks per second: 290.7. Projected total hours: 16.8
#
# Chunks embedded: 9000 (0.01081%). Total tokens spent: 10598165. ($0.106). Total time: 10.97 minutes. Chunks per second: 288.8. Projected total hours: 16.91
#
# Chunks embedded: 1000 (0.01137%). Total tokens spent: 10706078. ($0.107). Total time: 11.1 minutes. Chunks per second: 300.4. Projected total hours: 16.26
#
# Chunks embedded: 2000 (0.01137%). Total tokens spent: 10760176. ($0.108). Total time: 11.16 minutes. Chunks per second: 298.8. Projected total hours: 16.34
#
# Chunks embedded: 3000 (0.01137%). Total tokens spent: 10818100. ($0.108). Total time: 11.22 minutes. Chunks per second: 297.2. Projected total hours: 16.43
#
# Chunks embedded: 4000 (0.01137%). Total tokens spent: 10873988. ($0.109). Total time: 11.28 minutes. Chunks per second: 295.5. Projected total hours: 16.53
#
# Chunks embedded: 5000 (0.01137%). Total tokens spent: 10929196. ($0.109). Total time: 11.34 minutes. Chunks per second: 293.9. Projected total hours: 16.62
#
# Chunks embedded: 6000 (0.01137%). Total tokens spent: 10986374. ($0.11). Total time: 11.4 minutes. Chunks per second: 292.4. Projected total hours: 16.7
#
# Chunks embedded: 7000 (0.01137%). Total tokens spent: 11040661. ($0.11). Total time: 11.46 minutes. Chunks per second: 290.9. Projected total hours: 16.79
#
# Chunks embedded: 8000 (0.01137%). Total tokens spent: 11095836. ($0.111). Total time: 11.52 minutes. Chunks per second: 289.2. Projected total hours: 16.89
#
# Chunks embedded: 9000 (0.01137%). Total tokens spent: 11152497. ($0.112). Total time: 11.59 minutes. Chunks per second: 287.6. Projected total hours: 16.98
#
# Chunks embedded: 1000 (0.01194%). Total tokens spent: 11265386. ($0.113). Total time: 11.71 minutes. Chunks per second: 298.8. Projected total hours: 16.35
#
# Chunks embedded: 2000 (0.01194%). Total tokens spent: 11317652. ($0.113). Total time: 11.79 minutes. Chunks per second: 296.9. Projected total hours: 16.45
#
# Chunks embedded: 3000 (0.01194%). Total tokens spent: 11373305. ($0.114). Total time: 11.84 minutes. Chunks per second: 295.5. Projected total hours: 16.53
#
# Chunks embedded: 4000 (0.01194%). Total tokens spent: 11427683. ($0.114). Total time: 11.91 minutes. Chunks per second: 293.9. Projected total hours: 16.62
#
# Chunks embedded: 5000 (0.01194%). Total tokens spent: 11485057. ($0.115). Total time: 11.98 minutes. Chunks per second: 292.2. Projected total hours: 16.71
#
# Chunks embedded: 6000 (0.01194%). Total tokens spent: 11537880. ($0.115). Total time: 12.03 minutes. Chunks per second: 290.8. Projected total hours: 16.79
#
# Chunks embedded: 7000 (0.01194%). Total tokens spent: 11594487. ($0.116). Total time: 12.1 minutes. Chunks per second: 289.3. Projected total hours: 16.88
#
# Chunks embedded: 8000 (0.01194%). Total tokens spent: 11651083. ($0.117). Total time: 12.15 minutes. Chunks per second: 288.0. Projected total hours: 16.96
#
# Chunks embedded: 9000 (0.01194%). Total tokens spent: 11705118. ($0.117). Total time: 12.23 minutes. Chunks per second: 286.1. Projected total hours: 17.07
#
# Chunks embedded: 1000 (0.01251%). Total tokens spent: 11816917. ($0.118). Total time: 12.35 minutes. Chunks per second: 296.9. Projected total hours: 16.45
#
# Chunks embedded: 2000 (0.01251%). Total tokens spent: 11872528. ($0.119). Total time: 12.41 minutes. Chunks per second: 295.4. Projected total hours: 16.53
#
# Chunks embedded: 3000 (0.01251%). Total tokens spent: 11926638. ($0.119). Total time: 12.5 minutes. Chunks per second: 293.3. Projected total hours: 16.65
#
# Chunks embedded: 4000 (0.01251%). Total tokens spent: 11980266. ($0.12). Total time: 12.55 minutes. Chunks per second: 292.2. Projected total hours: 16.71
#
# Chunks embedded: 5000 (0.01251%). Total tokens spent: 12036427. ($0.12). Total time: 12.62 minutes. Chunks per second: 290.6. Projected total hours: 16.81
#
# Chunks embedded: 6000 (0.01251%). Total tokens spent: 12093031. ($0.121). Total time: 12.67 minutes. Chunks per second: 289.3. Projected total hours: 16.88
#
# Chunks embedded: 7000 (0.01251%). Total tokens spent: 12147855. ($0.121). Total time: 12.74 minutes. Chunks per second: 287.8. Projected total hours: 16.97
#
# Chunks embedded: 8000 (0.01251%). Total tokens spent: 12203467. ($0.122). Total time: 12.8 minutes. Chunks per second: 286.5. Projected total hours: 17.05
#
# Chunks embedded: 9000 (0.01251%). Total tokens spent: 12255777. ($0.123). Total time: 12.87 minutes. Chunks per second: 284.8. Projected total hours: 17.15
#
# Chunks embedded: 1000 (0.01308%). Total tokens spent: 12369089. ($0.124). Total time: 12.99 minutes. Chunks per second: 295.1. Projected total hours: 16.55
#
# Chunks embedded: 2000 (0.01308%). Total tokens spent: 12421827. ($0.124). Total time: 13.05 minutes. Chunks per second: 293.7. Projected total hours: 16.63
#
# Chunks embedded: 3000 (0.01308%). Total tokens spent: 12478739. ($0.125). Total time: 13.12 minutes. Chunks per second: 292.1. Projected total hours: 16.72
#
# Chunks embedded: 4000 (0.01308%). Total tokens spent: 12537003. ($0.125). Total time: 13.18 minutes. Chunks per second: 290.9. Projected total hours: 16.79
#
# Chunks embedded: 5000 (0.01308%). Total tokens spent: 12592562. ($0.126). Total time: 13.24 minutes. Chunks per second: 289.6. Projected total hours: 16.87
#
# Chunks embedded: 6000 (0.01308%). Total tokens spent: 12645871. ($0.126). Total time: 13.31 minutes. Chunks per second: 287.9. Projected total hours: 16.96
#
# Chunks embedded: 7000 (0.01308%). Total tokens spent: 12698508. ($0.127). Total time: 13.36 minutes. Chunks per second: 286.9. Projected total hours: 17.02
#
# Chunks embedded: 8000 (0.01308%). Total tokens spent: 12754523. ($0.128). Total time: 13.43 minutes. Chunks per second: 285.5. Projected total hours: 17.11
#
# Chunks embedded: 9000 (0.01308%). Total tokens spent: 12807197. ($0.128). Total time: 13.48 minutes. Chunks per second: 284.5. Projected total hours: 17.17
#
# Chunks embedded: 1000 (0.01365%). Total tokens spent: 12912677. ($0.129). Total time: 13.62 minutes. Chunks per second: 293.7. Projected total hours: 16.63
#
# Chunks embedded: 2000 (0.01365%). Total tokens spent: 12965387. ($0.13). Total time: 13.66 minutes. Chunks per second: 292.7. Projected total hours: 16.68
#
# Chunks embedded: 3000 (0.01365%). Total tokens spent: 13016961. ($0.13). Total time: 13.72 minutes. Chunks per second: 291.5. Projected total hours: 16.76
#
# Chunks embedded: 4000 (0.01365%). Total tokens spent: 13070406. ($0.131). Total time: 13.79 minutes. Chunks per second: 290.0. Projected total hours: 16.84
#
# Chunks embedded: 5000 (0.01365%). Total tokens spent: 13128098. ($0.131). Total time: 13.86 minutes. Chunks per second: 288.6. Projected total hours: 16.92
#
# Chunks embedded: 6000 (0.01365%). Total tokens spent: 13184058. ($0.132). Total time: 13.92 minutes. Chunks per second: 287.4. Projected total hours: 17.0
#
# Chunks embedded: 7000 (0.01365%). Total tokens spent: 13235504. ($0.132). Total time: 23.99 minutes. Chunks per second: 166.8. Projected total hours: 29.29
#
# Chunks embedded: 8000 (0.01365%). Total tokens spent: 13289152. ($0.133). Total time: 24.01 minutes. Chunks per second: 166.6. Projected total hours: 29.32
#
# Chunks embedded: 9000 (0.01365%). Total tokens spent: 13341695. ($0.133). Total time: 24.05 minutes. Chunks per second: 166.3. Projected total hours: 29.36
#
# Chunks embedded: 1000 (0.01422%). Total tokens spent: 13449335. ($0.134). Total time: 24.1 minutes. Chunks per second: 172.9. Projected total hours: 28.25
#
# Chunks embedded: 2000 (0.01422%). Total tokens spent: 13503052. ($0.135). Total time: 24.13 minutes. Chunks per second: 172.6. Projected total hours: 28.29
#
# Chunks embedded: 3000 (0.01422%). Total tokens spent: 13556741. ($0.136). Total time: 24.16 minutes. Chunks per second: 172.4. Projected total hours: 28.33
#
# Chunks embedded: 4000 (0.01422%). Total tokens spent: 13611040. ($0.136). Total time: 24.19 minutes. Chunks per second: 172.2. Projected total hours: 28.36
#
# Chunks embedded: 5000 (0.01422%). Total tokens spent: 13665122. ($0.137). Total time: 24.22 minutes. Chunks per second: 172.1. Projected total hours: 28.39
#
# Chunks embedded: 6000 (0.01422%). Total tokens spent: 13718470. ($0.137). Total time: 24.24 minutes. Chunks per second: 171.9. Projected total hours: 28.42
#
# Chunks embedded: 7000 (0.01422%). Total tokens spent: 13772431. ($0.138). Total time: 24.28 minutes. Chunks per second: 171.6. Projected total hours: 28.46
#
# Chunks embedded: 8000 (0.01422%). Total tokens spent: 13830171. ($0.138). Total time: 24.31 minutes. Chunks per second: 171.4. Projected total hours: 28.49
#
# Chunks embedded: 9000 (0.01422%). Total tokens spent: 13885990. ($0.139). Total time: 24.33 minutes. Chunks per second: 171.2. Projected total hours: 28.52
#
# Chunks embedded: 1000 (0.01479%). Total tokens spent: 13997101. ($0.14). Total time: 24.39 minutes. Chunks per second: 177.7. Projected total hours: 27.49
#
# Chunks embedded: 2000 (0.01479%). Total tokens spent: 14050929. ($0.141). Total time: 24.42 minutes. Chunks per second: 177.4. Projected total hours: 27.52
#
# Chunks embedded: 3000 (0.01479%). Total tokens spent: 14102128. ($0.141). Total time: 24.45 minutes. Chunks per second: 177.2. Projected total hours: 27.56
#
# Chunks embedded: 4000 (0.01479%). Total tokens spent: 14157394. ($0.142). Total time: 24.48 minutes. Chunks per second: 177.0. Projected total hours: 27.59
#
# Chunks embedded: 5000 (0.01479%). Total tokens spent: 14212606. ($0.142). Total time: 24.52 minutes. Chunks per second: 176.8. Projected total hours: 27.63
#
# Chunks embedded: 6000 (0.01479%). Total tokens spent: 14268959. ($0.143). Total time: 24.55 minutes. Chunks per second: 176.5. Projected total hours: 27.66
#
# Chunks embedded: 7000 (0.01479%). Total tokens spent: 14325024. ($0.143). Total time: 24.57 minutes. Chunks per second: 176.4. Projected total hours: 27.69
#
# Chunks embedded: 8000 (0.01479%). Total tokens spent: 14380887. ($0.144). Total time: 24.6 minutes. Chunks per second: 176.2. Projected total hours: 27.73
#
# Chunks embedded: 9000 (0.01479%). Total tokens spent: 14436917. ($0.144). Total time: 24.64 minutes. Chunks per second: 175.9. Projected total hours: 27.77
#
# Chunks embedded: 1000 (0.01536%). Total tokens spent: 14548970. ($0.145). Total time: 24.69 minutes. Chunks per second: 182.3. Projected total hours: 26.8
#
# Chunks embedded: 2000 (0.01536%). Total tokens spent: 14604429. ($0.146). Total time: 24.72 minutes. Chunks per second: 182.0. Projected total hours: 26.83
#
# Chunks embedded: 3000 (0.01536%). Total tokens spent: 14657351. ($0.147). Total time: 24.76 minutes. Chunks per second: 181.8. Projected total hours: 26.87
#
# Chunks embedded: 4000 (0.01536%). Total tokens spent: 14710134. ($0.147). Total time: 24.79 minutes. Chunks per second: 181.6. Projected total hours: 26.9
#
# Chunks embedded: 5000 (0.01536%). Total tokens spent: 14763631. ($0.148). Total time: 24.81 minutes. Chunks per second: 181.3. Projected total hours: 26.93
#
# Chunks embedded: 6000 (0.01536%). Total tokens spent: 14814598. ($0.148). Total time: 24.87 minutes. Chunks per second: 181.0. Projected total hours: 26.99
#
# Chunks embedded: 7000 (0.01536%). Total tokens spent: 14868664. ($0.149). Total time: 24.92 minutes. Chunks per second: 180.6. Projected total hours: 27.04
#
# Chunks embedded: 8000 (0.01536%). Total tokens spent: 14921578. ($0.149). Total time: 24.98 minutes. Chunks per second: 180.1. Projected total hours: 27.11
#
# Chunks embedded: 9000 (0.01536%). Total tokens spent: 14974602. ($0.15). Total time: 25.04 minutes. Chunks per second: 179.7. Projected total hours: 27.18
#
# Chunks embedded: 1000 (0.01592%). Total tokens spent: 15085631. ($0.151). Total time: 25.16 minutes. Chunks per second: 185.5. Projected total hours: 26.33
#
# Chunks embedded: 2000 (0.01592%). Total tokens spent: 15139931. ($0.151). Total time: 25.23 minutes. Chunks per second: 184.9. Projected total hours: 26.41
#
# Chunks embedded: 3000 (0.01592%). Total tokens spent: 15192429. ($0.152). Total time: 25.28 minutes. Chunks per second: 184.6. Projected total hours: 26.46
#
# Chunks embedded: 4000 (0.01592%). Total tokens spent: 15246173. ($0.152). Total time: 25.34 minutes. Chunks per second: 184.1. Projected total hours: 26.53
#
# Chunks embedded: 5000 (0.01592%). Total tokens spent: 15301140. ($0.153). Total time: 25.42 minutes. Chunks per second: 183.6. Projected total hours: 26.6
#
# Chunks embedded: 6000 (0.01592%). Total tokens spent: 15355856. ($0.154). Total time: 25.47 minutes. Chunks per second: 183.2. Projected total hours: 26.65
#
# Chunks embedded: 7000 (0.01592%). Total tokens spent: 15409757. ($0.154). Total time: 25.53 minutes. Chunks per second: 182.8. Projected total hours: 26.72
#
# Chunks embedded: 8000 (0.01592%). Total tokens spent: 15464237. ($0.155). Total time: 25.59 minutes. Chunks per second: 182.3. Projected total hours: 26.78
#
# Chunks embedded: 9000 (0.01592%). Total tokens spent: 15516738. ($0.155). Total time: 25.66 minutes. Chunks per second: 181.9. Projected total hours: 26.85
#
# Chunks embedded: 1000 (0.01649%). Total tokens spent: 15622984. ($0.156). Total time: 25.78 minutes. Chunks per second: 187.5. Projected total hours: 26.05
#
# Chunks embedded: 2000 (0.01649%). Total tokens spent: 15675768. ($0.157). Total time: 25.84 minutes. Chunks per second: 187.0. Projected total hours: 26.11
#
# Chunks embedded: 3000 (0.01649%). Total tokens spent: 15731951. ($0.157). Total time: 25.91 minutes. Chunks per second: 186.6. Projected total hours: 26.18
#
# Chunks embedded: 4000 (0.01649%). Total tokens spent: 15787731. ($0.158). Total time: 25.96 minutes. Chunks per second: 186.2. Projected total hours: 26.24
#
# Chunks embedded: 5000 (0.01649%). Total tokens spent: 15840052. ($0.158). Total time: 26.02 minutes. Chunks per second: 185.8. Projected total hours: 26.29
#
# Chunks embedded: 6000 (0.01649%). Total tokens spent: 15894429. ($0.159). Total time: 26.09 minutes. Chunks per second: 185.3. Projected total hours: 26.36
#
# Chunks embedded: 7000 (0.01649%). Total tokens spent: 15949639. ($0.159). Total time: 26.15 minutes. Chunks per second: 184.8. Projected total hours: 26.43
#
# Chunks embedded: 8000 (0.01649%). Total tokens spent: 16003119. ($0.16). Total time: 26.22 minutes. Chunks per second: 184.4. Projected total hours: 26.49
#
# Chunks embedded: 9000 (0.01649%). Total tokens spent: 16057689. ($0.161). Total time: 26.27 minutes. Chunks per second: 184.0. Projected total hours: 26.55
#
# Chunks embedded: 1000 (0.01706%). Total tokens spent: 16165257. ($0.162). Total time: 26.4 minutes. Chunks per second: 189.4. Projected total hours: 25.79
#
# Chunks embedded: 2000 (0.01706%). Total tokens spent: 16220062. ($0.162). Total time: 26.46 minutes. Chunks per second: 188.9. Projected total hours: 25.85
#
# Chunks embedded: 3000 (0.01706%). Total tokens spent: 16276622. ($0.163). Total time: 26.53 minutes. Chunks per second: 188.5. Projected total hours: 25.91
#
# Chunks embedded: 4000 (0.01706%). Total tokens spent: 16338673. ($0.163). Total time: 26.59 minutes. Chunks per second: 188.1. Projected total hours: 25.97
#
# Chunks embedded: 5000 (0.01706%). Total tokens spent: 16393936. ($0.164). Total time: 26.65 minutes. Chunks per second: 187.6. Projected total hours: 26.03
#
# Chunks embedded: 6000 (0.01706%). Total tokens spent: 16447772. ($0.164). Total time: 26.72 minutes. Chunks per second: 187.2. Projected total hours: 26.1
#
# Chunks embedded: 7000 (0.01706%). Total tokens spent: 16499872. ($0.165). Total time: 26.77 minutes. Chunks per second: 186.8. Projected total hours: 26.15
#
# Chunks embedded: 8000 (0.01706%). Total tokens spent: 16554348. ($0.166). Total time: 26.84 minutes. Chunks per second: 186.3. Projected total hours: 26.21
#
# Chunks embedded: 9000 (0.01706%). Total tokens spent: 16609860. ($0.166). Total time: 26.89 minutes. Chunks per second: 185.9. Projected total hours: 26.27
#
# Chunks embedded: 1000 (0.01763%). Total tokens spent: 16717870. ($0.167). Total time: 27.02 minutes. Chunks per second: 191.2. Projected total hours: 25.54
#
# Chunks embedded: 2000 (0.01763%). Total tokens spent: 16768617. ($0.168). Total time: 27.08 minutes. Chunks per second: 190.8. Projected total hours: 25.6
#
# Chunks embedded: 3000 (0.01763%). Total tokens spent: 16823651. ($0.168). Total time: 27.15 minutes. Chunks per second: 190.3. Projected total hours: 25.67
#
# Chunks embedded: 4000 (0.01763%). Total tokens spent: 16878464. ($0.169). Total time: 27.21 minutes. Chunks per second: 189.9. Projected total hours: 25.72
#
# Chunks embedded: 5000 (0.01763%). Total tokens spent: 16929888. ($0.169). Total time: 27.26 minutes. Chunks per second: 189.5. Projected total hours: 25.77
#
# Chunks embedded: 6000 (0.01763%). Total tokens spent: 16988256. ($0.17). Total time: 27.33 minutes. Chunks per second: 189.1. Projected total hours: 25.83
#
# Chunks embedded: 7000 (0.01763%). Total tokens spent: 17042372. ($0.17). Total time: 27.39 minutes. Chunks per second: 188.6. Projected total hours: 25.89
#
# Chunks embedded: 8000 (0.01763%). Total tokens spent: 17095471. ($0.171). Total time: 27.45 minutes. Chunks per second: 188.2. Projected total hours: 25.95
#
# Chunks embedded: 9000 (0.01763%). Total tokens spent: 17147509. ($0.171). Total time: 27.52 minutes. Chunks per second: 187.8. Projected total hours: 26.01
#
# Chunks embedded: 1000 (0.0182%). Total tokens spent: 17259482. ($0.173). Total time: 27.64 minutes. Chunks per second: 192.9. Projected total hours: 25.31
#
# Chunks embedded: 2000 (0.0182%). Total tokens spent: 17312114. ($0.173). Total time: 27.71 minutes. Chunks per second: 192.5. Projected total hours: 25.37
#
# Chunks embedded: 3000 (0.0182%). Total tokens spent: 17366960. ($0.174). Total time: 27.77 minutes. Chunks per second: 192.1. Projected total hours: 25.43
#
# Chunks embedded: 4000 (0.0182%). Total tokens spent: 17421256. ($0.174). Total time: 27.84 minutes. Chunks per second: 191.6. Projected total hours: 25.49
#
# Chunks embedded: 5000 (0.0182%). Total tokens spent: 17473198. ($0.175). Total time: 27.9 minutes. Chunks per second: 191.1. Projected total hours: 25.55
#
# Chunks embedded: 6000 (0.0182%). Total tokens spent: 17525008. ($0.175). Total time: 27.96 minutes. Chunks per second: 190.7. Projected total hours: 25.61
#
# Chunks embedded: 7000 (0.0182%). Total tokens spent: 17578130. ($0.176). Total time: 28.03 minutes. Chunks per second: 190.2. Projected total hours: 25.67
#
# Chunks embedded: 8000 (0.0182%). Total tokens spent: 17632829. ($0.176). Total time: 28.1 minutes. Chunks per second: 189.8. Projected total hours: 25.73
#
# Chunks embedded: 9000 (0.0182%). Total tokens spent: 17687608. ($0.177). Total time: 28.15 minutes. Chunks per second: 189.4. Projected total hours: 25.78
#
# Chunks embedded: 1000 (0.01877%). Total tokens spent: 17796131. ($0.178). Total time: 28.28 minutes. Chunks per second: 194.5. Projected total hours: 25.11
#
# Chunks embedded: 2000 (0.01877%). Total tokens spent: 17849989. ($0.178). Total time: 28.35 minutes. Chunks per second: 194.0. Projected total hours: 25.17
#
# Chunks embedded: 3000 (0.01877%). Total tokens spent: 17910074. ($0.179). Total time: 28.41 minutes. Chunks per second: 193.6. Projected total hours: 25.23
#
# Chunks embedded: 4000 (0.01877%). Total tokens spent: 17964977. ($0.18). Total time: 28.47 minutes. Chunks per second: 193.2. Projected total hours: 25.28
#
# Chunks embedded: 5000 (0.01877%). Total tokens spent: 18017815. ($0.18). Total time: 28.53 minutes. Chunks per second: 192.8. Projected total hours: 25.33
#
# Chunks embedded: 6000 (0.01877%). Total tokens spent: 18072987. ($0.181). Total time: 28.59 minutes. Chunks per second: 192.4. Projected total hours: 25.39
#
# Chunks embedded: 7000 (0.01877%). Total tokens spent: 18127194. ($0.181). Total time: 28.65 minutes. Chunks per second: 192.0. Projected total hours: 25.44
#
# Chunks embedded: 8000 (0.01877%). Total tokens spent: 18181566. ($0.182). Total time: 28.71 minutes. Chunks per second: 191.6. Projected total hours: 25.5
#
# Chunks embedded: 9000 (0.01877%). Total tokens spent: 18237655. ($0.182). Total time: 28.78 minutes. Chunks per second: 191.1. Projected total hours: 25.56
#
# Chunks embedded: 1000 (0.01934%). Total tokens spent: 18350137. ($0.184). Total time: 28.9 minutes. Chunks per second: 196.1. Projected total hours: 24.91
#
# Chunks embedded: 2000 (0.01934%). Total tokens spent: 18403791. ($0.184). Total time: 28.96 minutes. Chunks per second: 195.7. Projected total hours: 24.96
#
# Chunks embedded: 3000 (0.01934%). Total tokens spent: 18458789. ($0.185). Total time: 29.02 minutes. Chunks per second: 195.3. Projected total hours: 25.01
#
# Chunks embedded: 4000 (0.01934%). Total tokens spent: 18514786. ($0.185). Total time: 29.09 minutes. Chunks per second: 194.8. Projected total hours: 25.08
#
# Chunks embedded: 5000 (0.01934%). Total tokens spent: 18566903. ($0.186). Total time: 29.14 minutes. Chunks per second: 194.4. Projected total hours: 25.12
#
# Chunks embedded: 6000 (0.01934%). Total tokens spent: 18620368. ($0.186). Total time: 29.21 minutes. Chunks per second: 194.0. Projected total hours: 25.17
#
# Chunks embedded: 7000 (0.01934%). Total tokens spent: 18671220. ($0.187). Total time: 29.27 minutes. Chunks per second: 193.6. Projected total hours: 25.23
#
# Chunks embedded: 8000 (0.01934%). Total tokens spent: 18723996. ($0.187). Total time: 29.35 minutes. Chunks per second: 193.1. Projected total hours: 25.3
#
# Chunks embedded: 9000 (0.01934%). Total tokens spent: 18777052. ($0.188). Total time: 29.41 minutes. Chunks per second: 192.7. Projected total hours: 25.35
#
# Chunks embedded: 1000 (0.01991%). Total tokens spent: 18883834. ($0.189). Total time: 29.54 minutes. Chunks per second: 197.5. Projected total hours: 24.73
#
# ...
#
# Chunks embedded: 2000 (0.99417%). Total tokens spent: 1033132292. ($10.331). Total time: 1182.63 minutes. Chunks per second: 246.3. Projected total hours: 19.83
#
# Chunks embedded: 3000 (0.99417%). Total tokens spent: 1033204736. ($10.332). Total time: 1182.7 minutes. Chunks per second: 246.3. Projected total hours: 19.83
#
# Chunks embedded: 4000 (0.99417%). Total tokens spent: 1033270874. ($10.333). Total time: 1182.76 minutes. Chunks per second: 246.3. Projected total hours: 19.83
#
# Chunks embedded: 5000 (0.99417%). Total tokens spent: 1033339705. ($10.333). Total time: 1182.8 minutes. Chunks per second: 246.3. Projected total hours: 19.83
#
# Chunks embedded: 6000 (0.99417%). Total tokens spent: 1033413339. ($10.334). Total time: 1182.85 minutes. Chunks per second: 246.3. Projected total hours: 19.83
#
# Chunks embedded: 7000 (0.99417%). Total tokens spent: 1033490331. ($10.335). Total time: 1182.89 minutes. Chunks per second: 246.3. Projected total hours: 19.83
#
# Chunks embedded: 8000 (0.99417%). Total tokens spent: 1033561473. ($10.336). Total time: 1182.99 minutes. Chunks per second: 246.3. Projected total hours: 19.83
#
# Chunks embedded: 9000 (0.99417%). Total tokens spent: 1033625284. ($10.336). Total time: 1183.04 minutes. Chunks per second: 246.3. Projected total hours: 19.83
#
# Chunks embedded: 1000 (0.99474%). Total tokens spent: 1033764215. ($10.338). Total time: 1183.18 minutes. Chunks per second: 246.4. Projected total hours: 19.82
#
# Chunks embedded: 2000 (0.99474%). Total tokens spent: 1033837036. ($10.338). Total time: 1183.27 minutes. Chunks per second: 246.4. Projected total hours: 19.83
#
# Chunks embedded: 3000 (0.99474%). Total tokens spent: 1033909823. ($10.339). Total time: 1183.32 minutes. Chunks per second: 246.3. Projected total hours: 19.83
#
# Chunks embedded: 4000 (0.99474%). Total tokens spent: 1033987598. ($10.34). Total time: 1183.37 minutes. Chunks per second: 246.3. Projected total hours: 19.83
#
# Chunks embedded: 5000 (0.99474%). Total tokens spent: 1034065552. ($10.341). Total time: 1183.41 minutes. Chunks per second: 246.3. Projected total hours: 19.83
#
# Chunks embedded: 6000 (0.99474%). Total tokens spent: 1034139499. ($10.341). Total time: 1183.54 minutes. Chunks per second: 246.3. Projected total hours: 19.83
#
# Chunks embedded: 7000 (0.99474%). Total tokens spent: 1034207152. ($10.342). Total time: 1183.61 minutes. Chunks per second: 246.3. Projected total hours: 19.83
#
# Chunks embedded: 8000 (0.99474%). Total tokens spent: 1034269747. ($10.343). Total time: 1183.68 minutes. Chunks per second: 246.3. Projected total hours: 19.83
#
# Chunks embedded: 9000 (0.99474%). Total tokens spent: 1034343581. ($10.343). Total time: 1183.74 minutes. Chunks per second: 246.3. Projected total hours: 19.83
#
# Chunks embedded: 1000 (0.99531%). Total tokens spent: 1034475616. ($10.345). Total time: 1183.87 minutes. Chunks per second: 246.4. Projected total hours: 19.82
#
# Chunks embedded: 2000 (0.99531%). Total tokens spent: 1034548390. ($10.345). Total time: 1183.92 minutes. Chunks per second: 246.4. Projected total hours: 19.83
#
# Chunks embedded: 3000 (0.99531%). Total tokens spent: 1034621714. ($10.346). Total time: 1184.02 minutes. Chunks per second: 246.3. Projected total hours: 19.83
#
# Chunks embedded: 4000 (0.99531%). Total tokens spent: 1034686767. ($10.347). Total time: 1184.08 minutes. Chunks per second: 246.3. Projected total hours: 19.83
#
# Chunks embedded: 5000 (0.99531%). Total tokens spent: 1034761226. ($10.348). Total time: 1184.15 minutes. Chunks per second: 246.3. Projected total hours: 19.83
#
# Chunks embedded: 6000 (0.99531%). Total tokens spent: 1034824706. ($10.348). Total time: 1184.2 minutes. Chunks per second: 246.3. Projected total hours: 19.83
#
# Chunks embedded: 7000 (0.99531%). Total tokens spent: 1034897731. ($10.349). Total time: 1184.29 minutes. Chunks per second: 246.3. Projected total hours: 19.83
#
# Chunks embedded: 8000 (0.99531%). Total tokens spent: 1034966971. ($10.35). Total time: 1184.36 minutes. Chunks per second: 246.3. Projected total hours: 19.83
#
# Chunks embedded: 9000 (0.99531%). Total tokens spent: 1035030155. ($10.35). Total time: 1184.43 minutes. Chunks per second: 246.3. Projected total hours: 19.83
#
# Chunks embedded: 1000 (0.99588%). Total tokens spent: 1035177143. ($10.352). Total time: 1184.55 minutes. Chunks per second: 246.4. Projected total hours: 19.82
#
# Chunks embedded: 2000 (0.99588%). Total tokens spent: 1035240490. ($10.352). Total time: 1184.61 minutes. Chunks per second: 246.4. Projected total hours: 19.83
#
# Chunks embedded: 3000 (0.99588%). Total tokens spent: 1035302033. ($10.353). Total time: 1184.67 minutes. Chunks per second: 246.3. Projected total hours: 19.83
#
# Chunks embedded: 4000 (0.99588%). Total tokens spent: 1035381240. ($10.354). Total time: 1184.76 minutes. Chunks per second: 246.3. Projected total hours: 19.83
#
# Chunks embedded: 5000 (0.99588%). Total tokens spent: 1035451893. ($10.355). Total time: 1184.81 minutes. Chunks per second: 246.3. Projected total hours: 19.83
#
# Chunks embedded: 6000 (0.99588%). Total tokens spent: 1035513980. ($10.355). Total time: 1184.9 minutes. Chunks per second: 246.3. Projected total hours: 19.83
#
# Chunks embedded: 7000 (0.99588%). Total tokens spent: 1035581315. ($10.356). Total time: 1184.96 minutes. Chunks per second: 246.3. Projected total hours: 19.83
#
# Chunks embedded: 8000 (0.99588%). Total tokens spent: 1035646916. ($10.356). Total time: 1185.03 minutes. Chunks per second: 246.3. Projected total hours: 19.83
#
# Chunks embedded: 9000 (0.99588%). Total tokens spent: 1035725375. ($10.357). Total time: 1185.09 minutes. Chunks per second: 246.3. Projected total hours: 19.83
#
# Chunks embedded: 1000 (0.99645%). Total tokens spent: 1035861523. ($10.359). Total time: 1185.2 minutes. Chunks per second: 246.4. Projected total hours: 19.82
#
# Chunks embedded: 2000 (0.99645%). Total tokens spent: 1035929355. ($10.359). Total time: 1185.24 minutes. Chunks per second: 246.4. Projected total hours: 19.82
#
# Chunks embedded: 3000 (0.99645%). Total tokens spent: 1036006179. ($10.36). Total time: 1185.3 minutes. Chunks per second: 246.4. Projected total hours: 19.83
#
# Chunks embedded: 4000 (0.99645%). Total tokens spent: 1036091145. ($10.361). Total time: 1185.44 minutes. Chunks per second: 246.3. Projected total hours: 19.83
#
# Chunks embedded: 5000 (0.99645%). Total tokens spent: 1036157981. ($10.362). Total time: 1185.5 minutes. Chunks per second: 246.3. Projected total hours: 19.83
#
# Chunks embedded: 6000 (0.99645%). Total tokens spent: 1036224916. ($10.362). Total time: 1185.56 minutes. Chunks per second: 246.3. Projected total hours: 19.83
#
# Chunks embedded: 7000 (0.99645%). Total tokens spent: 1036283859. ($10.363). Total time: 1185.64 minutes. Chunks per second: 246.3. Projected total hours: 19.83
#
# Chunks embedded: 8000 (0.99645%). Total tokens spent: 1036353351. ($10.364). Total time: 1185.69 minutes. Chunks per second: 246.3. Projected total hours: 19.83
#
# Chunks embedded: 9000 (0.99645%). Total tokens spent: 1036422291. ($10.364). Total time: 1185.77 minutes. Chunks per second: 246.3. Projected total hours: 19.83
#
# Chunks embedded: 1000 (0.99701%). Total tokens spent: 1036561892. ($10.366). Total time: 1185.9 minutes. Chunks per second: 246.4. Projected total hours: 19.82
#
# Chunks embedded: 2000 (0.99701%). Total tokens spent: 1036626636. ($10.366). Total time: 1185.98 minutes. Chunks per second: 246.3. Projected total hours: 19.83
#
# Chunks embedded: 3000 (0.99701%). Total tokens spent: 1036695150. ($10.367). Total time: 1186.03 minutes. Chunks per second: 246.3. Projected total hours: 19.83
#
# Chunks embedded: 4000 (0.99701%). Total tokens spent: 1036768642. ($10.368). Total time: 1186.1 minutes. Chunks per second: 246.3. Projected total hours: 19.83
#
# Chunks embedded: 5000 (0.99701%). Total tokens spent: 1036850691. ($10.369). Total time: 1186.17 minutes. Chunks per second: 246.3. Projected total hours: 19.83
#
# Chunks embedded: 6000 (0.99701%). Total tokens spent: 1036925760. ($10.369). Total time: 1186.25 minutes. Chunks per second: 246.3. Projected total hours: 19.83
#
# Chunks embedded: 7000 (0.99701%). Total tokens spent: 1036996197. ($10.37). Total time: 1186.3 minutes. Chunks per second: 246.3. Projected total hours: 19.83
#
# Chunks embedded: 8000 (0.99701%). Total tokens spent: 1037060791. ($10.371). Total time: 1186.35 minutes. Chunks per second: 246.3. Projected total hours: 19.83
#
# Chunks embedded: 9000 (0.99701%). Total tokens spent: 1037128457. ($10.371). Total time: 1186.44 minutes. Chunks per second: 246.3. Projected total hours: 19.83
#
# Chunks embedded: 1000 (0.99758%). Total tokens spent: 1037261535. ($10.373). Total time: 1186.58 minutes. Chunks per second: 246.4. Projected total hours: 19.82
#
# Chunks embedded: 2000 (0.99758%). Total tokens spent: 1037330942. ($10.373). Total time: 1186.64 minutes. Chunks per second: 246.4. Projected total hours: 19.83
#
# Chunks embedded: 3000 (0.99758%). Total tokens spent: 1037394452. ($10.374). Total time: 1186.7 minutes. Chunks per second: 246.3. Projected total hours: 19.83
#
# Chunks embedded: 4000 (0.99758%). Total tokens spent: 1037469864. ($10.375). Total time: 1186.75 minutes. Chunks per second: 246.3. Projected total hours: 19.83
#
# Chunks embedded: 5000 (0.99758%). Total tokens spent: 1037533628. ($10.375). Total time: 1186.85 minutes. Chunks per second: 246.3. Projected total hours: 19.83
#
# Chunks embedded: 6000 (0.99758%). Total tokens spent: 1037608022. ($10.376). Total time: 1186.89 minutes. Chunks per second: 246.3. Projected total hours: 19.83
#
# Chunks embedded: 7000 (0.99758%). Total tokens spent: 1037676854. ($10.377). Total time: 1186.94 minutes. Chunks per second: 246.3. Projected total hours: 19.83
#
# Chunks embedded: 8000 (0.99758%). Total tokens spent: 1037743822. ($10.377). Total time: 1187.05 minutes. Chunks per second: 246.3. Projected total hours: 19.83
#
# Chunks embedded: 9000 (0.99758%). Total tokens spent: 1037806246. ($10.378). Total time: 1187.09 minutes. Chunks per second: 246.3. Projected total hours: 19.83
#
# Chunks embedded: 1000 (0.99815%). Total tokens spent: 1037947809. ($10.379). Total time: 1187.31 minutes. Chunks per second: 246.4. Projected total hours: 19.83
#
# Chunks embedded: 2000 (0.99815%). Total tokens spent: 1038023073. ($10.38). Total time: 1187.35 minutes. Chunks per second: 246.3. Projected total hours: 19.83
#
# Chunks embedded: 3000 (0.99815%). Total tokens spent: 1038097356. ($10.381). Total time: 1187.4 minutes. Chunks per second: 246.3. Projected total hours: 19.83
#
# Chunks embedded: 4000 (0.99815%). Total tokens spent: 1038171582. ($10.382). Total time: 1187.48 minutes. Chunks per second: 246.3. Projected total hours: 19.83
#
# Chunks embedded: 5000 (0.99815%). Total tokens spent: 1038236376. ($10.382). Total time: 1187.55 minutes. Chunks per second: 246.3. Projected total hours: 19.83
#
# Chunks embedded: 6000 (0.99815%). Total tokens spent: 1038294566. ($10.383). Total time: 1187.61 minutes. Chunks per second: 246.3. Projected total hours: 19.83
#
# Chunks embedded: 7000 (0.99815%). Total tokens spent: 1038361090. ($10.384). Total time: 1187.65 minutes. Chunks per second: 246.3. Projected total hours: 19.83
#
# Chunks embedded: 8000 (0.99815%). Total tokens spent: 1038440783. ($10.384). Total time: 1187.71 minutes. Chunks per second: 246.3. Projected total hours: 19.83
#
# Chunks embedded: 9000 (0.99815%). Total tokens spent: 1038509365. ($10.385). Total time: 1187.75 minutes. Chunks per second: 246.3. Projected total hours: 19.83
#
# Chunks embedded: 1000 (0.99872%). Total tokens spent: 1038648038. ($10.386). Total time: 1187.95 minutes. Chunks per second: 246.4. Projected total hours: 19.82
#
# Chunks embedded: 2000 (0.99872%). Total tokens spent: 1038720914. ($10.387). Total time: 1188.02 minutes. Chunks per second: 246.3. Projected total hours: 19.83
#
# Chunks embedded: 3000 (0.99872%). Total tokens spent: 1038787512. ($10.388). Total time: 1188.09 minutes. Chunks per second: 246.3. Projected total hours: 19.83
#
# Chunks embedded: 4000 (0.99872%). Total tokens spent: 1038859499. ($10.389). Total time: 1188.15 minutes. Chunks per second: 246.3. Projected total hours: 19.83
#
# Chunks embedded: 5000 (0.99872%). Total tokens spent: 1038933714. ($10.389). Total time: 1188.22 minutes. Chunks per second: 246.3. Projected total hours: 19.83
#
# Chunks embedded: 6000 (0.99872%). Total tokens spent: 1039003731. ($10.39). Total time: 1188.28 minutes. Chunks per second: 246.3. Projected total hours: 19.83
#
# Chunks embedded: 7000 (0.99872%). Total tokens spent: 1039069795. ($10.391). Total time: 1188.33 minutes. Chunks per second: 246.3. Projected total hours: 19.83
#
# Chunks embedded: 8000 (0.99872%). Total tokens spent: 1039135520. ($10.391). Total time: 1188.41 minutes. Chunks per second: 246.3. Projected total hours: 19.83
#
# Chunks embedded: 9000 (0.99872%). Total tokens spent: 1039202266. ($10.392). Total time: 1188.48 minutes. Chunks per second: 246.3. Projected total hours: 19.83
#
# Chunks embedded: 1000 (0.99929%). Total tokens spent: 1039341705. ($10.393). Total time: 1188.62 minutes. Chunks per second: 246.4. Projected total hours: 19.82
#
# Chunks embedded: 2000 (0.99929%). Total tokens spent: 1039409062. ($10.394). Total time: 1188.68 minutes. Chunks per second: 246.4. Projected total hours: 19.83
#
# Chunks embedded: 3000 (0.99929%). Total tokens spent: 1039488760. ($10.395). Total time: 1188.73 minutes. Chunks per second: 246.3. Projected total hours: 19.83
#
# Chunks embedded: 4000 (0.99929%). Total tokens spent: 1039551328. ($10.396). Total time: 1188.81 minutes. Chunks per second: 246.3. Projected total hours: 19.83
#
# Chunks embedded: 5000 (0.99929%). Total tokens spent: 1039618878. ($10.396). Total time: 1188.89 minutes. Chunks per second: 246.3. Projected total hours: 19.83
#
# Chunks embedded: 6000 (0.99929%). Total tokens spent: 1039683563. ($10.397). Total time: 1188.94 minutes. Chunks per second: 246.3. Projected total hours: 19.83
#
# Chunks embedded: 7000 (0.99929%). Total tokens spent: 1039755650. ($10.398). Total time: 1189.02 minutes. Chunks per second: 246.3. Projected total hours: 19.83
#
# Chunks embedded: 8000 (0.99929%). Total tokens spent: 1039825373. ($10.398). Total time: 1189.09 minutes. Chunks per second: 246.3. Projected total hours: 19.83
#
# Chunks embedded: 9000 (0.99929%). Total tokens spent: 1039908133. ($10.399). Total time: 1189.17 minutes. Chunks per second: 246.3. Projected total hours: 19.83
#
# Chunks embedded: 1000 (0.99986%). Total tokens spent: 1040055747. ($10.401). Total time: 1189.27 minutes. Chunks per second: 246.4. Projected total hours: 19.82
#
# Chunks embedded: 2000 (0.99986%). Total tokens spent: 1040128659. ($10.401). Total time: 1189.37 minutes. Chunks per second: 246.3. Projected total hours: 19.83
#
# Chunks embedded: 3000 (0.99986%). Total tokens spent: 1040186760. ($10.402). Total time: 1189.44 minutes. Chunks per second: 246.3. Projected total hours: 19.83
#
# Chunks embedded: 4000 (0.99986%). Total tokens spent: 1040252421. ($10.403). Total time: 1189.51 minutes. Chunks per second: 246.3. Projected total hours: 19.83
#
# Chunks embedded: 5000 (0.99986%). Total tokens spent: 1040323771. ($10.403). Total time: 1189.58 minutes. Chunks per second: 246.3. Projected total hours: 19.83
#
# Chunks embedded: 6000 (0.99986%). Total tokens spent: 1040388943. ($10.404). Total time: 1189.65 minutes. Chunks per second: 246.3. Projected total hours: 19.83
#
# Chunks embedded: 7000 (0.99986%). Total tokens spent: 1040453207. ($10.405). Total time: 1189.71 minutes. Chunks per second: 246.3. Projected total hours: 19.83
#
# Chunks embedded: 8000 (0.99986%). Total tokens spent: 1040519262. ($10.405). Total time: 1189.75 minutes. Chunks per second: 246.3. Projected total hours: 19.83
#
# Chunks embedded: 9000 (0.99986%). Total tokens spent: 1040588148. ($10.406). Total time: 1189.88 minutes. Chunks per second: 246.2. Projected total hours: 19.83

# %%
# 1189 minutes to complete. Total tokens spent: 1040588148. About $20.

# %%
# df = []
# with open(OUT_FILE, 'r') as file:
#     for line in file:
#         df.append(json.loads(line.strip()))

# df = pd.DataFrame(df)

# df['d'] = df.embedding.apply(lambda x: np.frombuffer(base64.b64decode(x), dtype=PRECISION))
# df.d.apply(lambda x: x.dtype)
# df
