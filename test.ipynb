# %%
import pandas as pd
i = 0
with open('transformed/data/selected_articles.jsonl', 'r') as file:
    for line in file:
        i += 1
i
# Out:
# 637207

# %%
df
# Out:
#             id                                                url  \
# 0           12            https://en.wikipedia.org/wiki/Anarchism
# 1           39               https://en.wikipedia.org/wiki/Albedo
# 2          290                    https://en.wikipedia.org/wiki/A
# 3          303              https://en.wikipedia.org/wiki/Alabama
# 4          305             https://en.wikipedia.org/wiki/Achilles
# ...        ...                                                ...
# 68675  7017757  https://en.wikipedia.org/wiki/Archie%20Hahn%20...
# 68676  7017762  https://en.wikipedia.org/wiki/Hallelujah%2C%20...
# 68677  7017821  https://en.wikipedia.org/wiki/The%20Practical%...
# 68678  7018098   https://en.wikipedia.org/wiki/Wanda%20%28film%29
# 68679  7018181  https://en.wikipedia.org/wiki/Anonymous%20func...
#
#                      title                                               text  \
# 0                Anarchism  Anarchism is a political philosophy and moveme...
# ...
