# %%
# !pip install pandas
# Out:
# ...
#   Using cached numpy-2.4.4-cp312-cp312-win_amd64.whl.metadata (6.6 kB)
# ...
#   Using cached tzdata-2026.2-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/9.8 MB 8.5 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.3/9.8 MB 4.5 MB/s eta 0:00:02
#    ------- -------------------------------- 1.8/9.8 MB 3.2 MB/s eta 0:00:03
#    -------- ------------------------------- 2.1/9.8 MB 2.8 MB/s eta 0:00:03
#    --------- ------------------------------ 2.4/9.8 MB 2.6 MB/s eta 0:00:03
#    ---------- ----------------------------- 2.6/9.8 MB 2.3 MB/s eta 0:00:04
#    ------------ --------------------------- 3.1/9.8 MB 2.3 MB/s eta 0:00:03
#    ---------------- ----------------------- 3.9/9.8 MB 2.4 MB/s eta 0:00:03
#    ------------------ --------------------- 4.5/9.8 MB 2.4 MB/s eta 0:00:03
#    -------------------- ------------------- 5.0/9.8 MB 2.4 MB/s eta 0:00:02
# ...

# %%
# !pip install fastparquet
# Out:
# ...
#    ---------------------------------------- 0.0/667.9 kB ? eta -:--:--
#    ---------------------------------------- 667.9/667.9 kB 6.5 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ------------------ --------------------- 0.8/1.7 MB 5.6 MB/s eta 0:00:01
#    ---------------------------------------- 1.7/1.7 MB 5.8 MB/s eta 0:00:00
# ...
# [notice] A new release of pip is available: 25.0.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

df = pd.read_parquet('temp/wiki_0.parquet')
df['title_lower'] = df.title.apply(lambda x: x.lower())
df = df[df.title_lower.isin(links)].copy()

# %%
len(df)
# Out:
# 2944

# %%
df['sentences'] = df['text'].apply(lambda x: )

# %%
out = []
for idx, row in df.iterrows():
    for sentence in get_sentences(row['text'], MIN_SENTENCE_WORDS, MAX_SENTENCE_WORDS):
        out.append({
            'article_id': row['article_id'],
            'sentence': sentence,
        })

# %%
os.listdir('transformed')
# Out:
# ['wiki_0_sentences.csv']

# %%
import random
import os
import pandas as pd  

token_to_id = {}
id_to_token = {}
if 'token_to_id.csv' in os.listdir('transformed'):
    token_to_id_df = pd.read_csv('token_to_id')
    for _, row in token_to_id.iterrows():
        token_to_id[row['token']] = row['id']
        id_to_token[row['id']] = row['token']

df = pd.read_csv('transformed/wiki_0_sentences.csv')

def tokenize(input, output):
    for _, row in input.iterrows():
        for token in row['sentence'].strip().lower().split():
            if token in token_to_id:
                id = token_to_id[token]
            else:

            output.append({

            })
# Out:
#         article_id                                           sentence
# 21501          783  King of Macedon Accession In summer 336 BC, wh...
# 228494        4524  The P200 offered a subtraction capability and ...
# 216042        4356  The farmhouse was defended by the King's Germa...
# 395172     4826588  Conservative commentator Whittaker Chambers pu...
# 443130     5227492  Thus, the history of the mile run began in Eng...

# %%
s = get_sentences('bob', t, 10, 60)
# random.choice(s[1])
i = 3
s[i][1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[140], line 1
# ----> 1 s = get_sentences('bob', t, 10, 60)
#       2 # random.choice(s[1])
#       3 i = 3
#       4 s[i][1]
#
# TypeError: get_sentences() takes 3 positional arguments but 4 were given
